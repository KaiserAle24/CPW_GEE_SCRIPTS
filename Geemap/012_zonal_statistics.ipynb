# %% [markdown]
# <a href="https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/12_zonal_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap

# %%
import ee
import geemap
import os

# %%
geemap.show_youtube('ou-Xm3CLitM')

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
# Add Earth Engine dataset
dem = ee.Image('USGS/SRTMGL1_003')

# Set visualization parameters.
dem_vis = {
    'min': 0,
    'max': 4000,
    'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5'],
}

# Add Earth Engine DEM to map
Map.addLayer(dem, dem_vis, 'SRTM DEM')

# Add Landsat data to map
landsat = ee.Image('LANDSAT/LE7_TOA_5YEAR/1999_2003')

landsat_vis = {'bands': ['B4', 'B3', 'B2'], 'gamma': 1.4}
Map.addLayer(landsat, landsat_vis, "LE7_TOA_5YEAR/1999_2003")

states = ee.FeatureCollection("users/Alejandro_AmayaH/ESTATAL_NAL")
Map.addLayer(states, {}, 'MX States')

# %%
out_dir = os.path.join(os.path.expanduser('~'), 'Downloads')
out_dem_stats = os.path.join(out_dir, 'dem_stats.csv')

if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# Allowed output formats: csv, shp, json, kml, kmz
# Allowed statistics type: MEAN, MAXIMUM, MINIMUM, MEDIAN, STD, MIN_MAX, VARIANCE, SUM
geemap.zonal_statistics(dem, states, out_dem_stats, statistics_type='MEAN', scale=1000)
# Out:
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/50ad13e241d2ad564da553419a40fe53-0d9eb8cdd1bf215e4a4a4a169922ad73:getFeatures
# Please wait ...
# Data downloaded to C:\Users\PC\Downloads\dem_stats.csv

# %%
out_landsat_stats = os.path.join(out_dir, 'landsat_stats.csv')
geemap.zonal_statistics(
    landsat, states, out_landsat_stats, statistics_type='SUM', scale=1000
)
# Out:
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/1925c4a55369f7df46966dccf6b5fa03-dbe5223eb026a0ef743879cd3dafe48c:getFeatures
# Please wait ...
# Data downloaded to C:\Users\PC\Downloads\landsat_stats.csv

# %%
geemap.create_download_link(out_dem_stats)
# Out:
# <a download="dem_stats.csv" href="data:text/csv;base64,..." style="color:#0000FF;" target="_blank">Click here to download:  dem_stats.csv</a>

# %%
geemap.create_download_link(out_landsat_stats)
# Out:
# <a download="landsat_stats.csv" href="data:text/csv;base64,..." style="color:#0000FF;" target="_blank">Click here to download:  landsat_stats.csv</a>
