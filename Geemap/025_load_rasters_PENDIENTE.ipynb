# %% [markdown]
# <a href="https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/25_load_rasters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap

# %%
#!pip install googledrivedownloader

# %%
# !pip install localtileserver

# %%
# !pip install --find-links=https://girder.github.io/large_image_wheels --no-cache GDAL

# %% [markdown]
# To follow this tutorial, you need to install the [geemap] and [xarray_leaflet](https://github.com/davidbrochart/xarray_leaflet/tree/master/xarray_leaflet) Python packages. Use the following conda commands to create a conda env and install packages:
#
# - `conda create -n gee python`
# - `conda activate gee`
# - `conda install mamba -c conda-forge`
# - `mamba install geemap xarray_leaflet -c conda-forge`

# %% [markdown]
# Import libraries

# %%
import os
import geemap
import ee

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
dataset = ee.Image('USGS/GAP/CONUS/2011')

visualization = {
  'bands': ['landcover'],
  'min': 1.0,
  'max': 584.0,
}

Map.setCenter(-98.58, 38.14, 4)

Map.addLayer(dataset, visualization, 'GAP CONUS')

# %%
dataset = ee.Image('CGIAR/SRTM90_V4')
elevation = dataset.select('elevation')
slope = ee.Terrain.slope(elevation)
Map.setCenter(-112.8598, 36.2841, 10)
Map.addLayer(slope, {'min': 0, 'max': 60}, 'slope')

# %% [markdown]
# Specify input raster datasets

# %%
out_dir = os.path.expanduser('~/Downloads')

if not os.path.exists(out_dir):
    os.makedirs(out_dir)

landsat = os.path.join(out_dir, 'landsat.tif')
dem = os.path.join(out_dir, 'dem.tif')

# %% [markdown]
# Download samples raster datasets
#
# More datasets can be downloaded from https://viewer.nationalmap.gov/basic/

# %%
if not os.path.exists(landsat):
    landsat_url = 'https://drive.google.com/file/d/1EV38RjNxdwEozjc9m0FcO3LFgAoAX1Uw/view?usp=sharing'
    geemap.download_from_gdrive(landsat_url, 'landsat.tif', out_dir, unzip=False)

# %%
if not os.path.exists(dem):
    dem_url = 'https://drive.google.com/file/d/1vRkAWQYsLWCi6vcTMk8vLxoXMFbdMFn8/view?usp=sharing'
    geemap.download_from_gdrive(dem_url, 'dem.tif', out_dir, unzip=False)

# %% [markdown]
# Create an interactive map

# %%
Map = geemap.Map()

# %% [markdown]
# Add local raster datasets to the map
#
# More colormap can be found at https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
Map.add_raster(dem, palette ='terrain', layer_name='DEM')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\miniconda3\envs\xarray\Lib\site-packages\geemap\common.py:397, in check_package(name, URL)
#     396 try:
# --> 397     __import__(name.lower())
#     398 except Exception:
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\localtileserver\__init__.py:3
#       2 from localtileserver._version import __version__
# ----> 3 from localtileserver.client import RemoteTileClient, TileClient, get_or_create_tile_client
#       4 from localtileserver.report import Report
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\localtileserver\client.py:29
#      28 from localtileserver.configure import get_default_client_params
# ---> 29 from localtileserver.helpers import parse_shapely
#      30 from localtileserver.manager import AppManager
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\localtileserver\helpers.py:6
#       4 import numpy as np
# ----> 6 from localtileserver.tileserver.utilities import get_cache_dir
#       9 def get_extensions_from_driver(driver: str):
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\localtileserver\tileserver\__init__.py:2
#       1 # flake8: noqa: F401
# ----> 2 from localtileserver.tileserver import rest, urls, views
#       3 from localtileserver.tileserver.application import create_app, run_app
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\localtileserver\tileserver\rest.py:8
#       7 from PIL import Image, ImageDraw, ImageOps
# ----> 8 from flask import request, send_file
#       9 from flask_restx import Api, Resource as View
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\flask\__init__.py:7
#       6 from . import json as json
# ----> 7 from .app import Flask as Flask
#       8 from .app import Request as Request
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\flask\app.py:19
#      18 from werkzeug.exceptions import InternalServerError
# ---> 19 from werkzeug.routing import BuildError
#      20 from werkzeug.routing import Map
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\werkzeug\routing\__init__.py:123
#     122 from .exceptions import WebsocketMismatch as WebsocketMismatch
# --> 123 from .map import Map as Map
#     124 from .map import MapAdapter as MapAdapter
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\werkzeug\routing\map.py:19
#      18 from ..exceptions import NotFound
# ---> 19 from ..urls import _urlencode
#      20 from ..wsgi import get_host
#
# ImportError: cannot import name '_urlencode' from 'werkzeug.urls' (C:\Users\PC\miniconda3\envs\xarray\Lib\site-packages\werkzeug\urls.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1068\362680285.py in ?()
# ----> 1 Map.add_raster(dem, palette ='terrain', layer_name='DEM')
#
# ~\miniconda3\envs\xarray\Lib\site-packages\geemap\geemap.py in ?(self, source, band, palette, vmin, vmax, nodata, attribution, layer_name, **kwargs)
#    3640         if in_colab_shell():
#    3641             print("This add_raster() function is not supported in Colab.")
#    3642             return
#    3643
# -> 3644         tile_layer, tile_client = get_local_tile_layer(
#    3645             source,
#    3646             band=band,
#    3647             palette=palette,
#
# ~\miniconda3\envs\xarray\Lib\site-packages\geemap\common.py in ?(source, port, debug, projection, band, palette, vmin, vmax, nodata, attribution, tile_format, layer_name, return_client, **kwargs)
#   10551     warnings.filterwarnings("ignore")
#   10552
#   10553     output = widgets.Output()
#   10554
# > 10555     check_package(
#   10556         "localtileserver", URL="https://github.com/banesullivan/localtileserver"
#   10557     )
#   10558
#
# ~\miniconda3\envs\xarray\Lib\site-packages\geemap\common.py in ?(name, URL)
#     395 def check_package(name, URL=""):
#     396     try:
#     397         __import__(name.lower())
#     398     except Exception:
# --> 399         raise ImportError(
#     400             f"{name} is not installed. Please install it before proceeding. {URL}"
#     401         )
#
# ImportError: localtileserver is not installed. Please install it before proceeding. https://github.com/banesullivan/localtileserver

# %%
Map.add_raster(
    dem,
    band=None,
    palette=None,
    vmin=None,
    vmax=None,
    nodata=None,
    attribution=None,
    layer_name=None,
)

# %%
Map.add_raster(landsat, band=[5, 4, 3], layer_name='Landsat')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\miniconda3\envs\xarray\Lib\site-packages\geemap\common.py:397, in check_package(name, URL)
#     396 try:
# --> 397     __import__(name.lower())
#     398 except Exception:
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\localtileserver\__init__.py:3
#       2 from localtileserver._version import __version__
# ----> 3 from localtileserver.client import RemoteTileClient, TileClient, get_or_create_tile_client
#       4 from localtileserver.report import Report
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\localtileserver\client.py:29
#      28 from localtileserver.configure import get_default_client_params
# ---> 29 from localtileserver.helpers import parse_shapely
#      30 from localtileserver.manager import AppManager
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\localtileserver\helpers.py:6
#       4 import numpy as np
# ----> 6 from localtileserver.tileserver.utilities import get_cache_dir
#       9 def get_extensions_from_driver(driver: str):
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\localtileserver\tileserver\__init__.py:2
#       1 # flake8: noqa: F401
# ----> 2 from localtileserver.tileserver import rest, urls, views
#       3 from localtileserver.tileserver.application import create_app, run_app
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\localtileserver\tileserver\rest.py:8
#       7 from PIL import Image, ImageDraw, ImageOps
# ----> 8 from flask import request, send_file
#       9 from flask_restx import Api, Resource as View
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\flask\__init__.py:7
#       6 from . import json as json
# ----> 7 from .app import Flask as Flask
#       8 from .app import Request as Request
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\flask\app.py:19
#      18 from werkzeug.exceptions import InternalServerError
# ---> 19 from werkzeug.routing import BuildError
#      20 from werkzeug.routing import Map
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\werkzeug\routing\__init__.py:123
#     122 from .exceptions import WebsocketMismatch as WebsocketMismatch
# --> 123 from .map import Map as Map
#     124 from .map import MapAdapter as MapAdapter
#
# File ~\miniconda3\envs\xarray\Lib\site-packages\werkzeug\routing\map.py:19
#      18 from ..exceptions import NotFound
# ---> 19 from ..urls import _urlencode
#      20 from ..wsgi import get_host
#
# ImportError: cannot import name '_urlencode' from 'werkzeug.urls' (C:\Users\PC\miniconda3\envs\xarray\Lib\site-packages\werkzeug\urls.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1068\191682785.py in ?()
# ----> 1 Map.add_raster(landsat, band=[5, 4, 3], layer_name='Landsat')
#
# ~\miniconda3\envs\xarray\Lib\site-packages\geemap\geemap.py in ?(self, source, band, palette, vmin, vmax, nodata, attribution, layer_name, **kwargs)
#    3640         if in_colab_shell():
#    3641             print("This add_raster() function is not supported in Colab.")
#    3642             return
#    3643
# -> 3644         tile_layer, tile_client = get_local_tile_layer(
#    3645             source,
#    3646             band=band,
#    3647             palette=palette,
#
# ~\miniconda3\envs\xarray\Lib\site-packages\geemap\common.py in ?(source, port, debug, projection, band, palette, vmin, vmax, nodata, attribution, tile_format, layer_name, return_client, **kwargs)
#   10551     warnings.filterwarnings("ignore")
#   10552
#   10553     output = widgets.Output()
#   10554
# > 10555     check_package(
#   10556         "localtileserver", URL="https://github.com/banesullivan/localtileserver"
#   10557     )
#   10558
#
# ~\miniconda3\envs\xarray\Lib\site-packages\geemap\common.py in ?(name, URL)
#     395 def check_package(name, URL=""):
#     396     try:
#     397         __import__(name.lower())
#     398     except Exception:
# --> 399         raise ImportError(
#     400             f"{name} is not installed. Please install it before proceeding. {URL}"
#     401         )
#
# ImportError: localtileserver is not installed. Please install it before proceeding. https://github.com/banesullivan/localtileserver

# %% [markdown]
# Display the map

# %%
Map

# %%
conda install -c conda-forge localtileserver
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\PC\miniconda3\envs\xarray
#
#   added / updated specs:
#     - localtileserver
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aniso8601-9.0.1            |     pyhd8ed1ab_0          38 KB  conda-forge
#     flask-2.1.3                |     pyhd8ed1ab_0          71 KB  conda-forge
#     flask-caching-1.10.1       |     pyhd3eb1b0_0          29 KB
#     flask-cors-3.0.10          |     pyhd8ed1ab_0          15 KB  conda-forge
#     flask-restx-1.0.6          |     pyhd8ed1ab_0         2.3 MB  conda-forge
#     gdal-3.7.0                 |  py311hf43951c_1         1.5 MB  conda-forge
#     h11-0.14.0                 |     pyhd8ed1ab_0          47 KB  conda-forge
#     itsdangerous-2.1.2         |     pyhd8ed1ab_0          16 KB  conda-forge
#     large-image-1.21.0         |     pyhd8ed1ab_0          61 KB  conda-forge
#     large-image-source-gdal-1.21.0|     pyhd8ed1ab_0          25 KB  conda-forge
#     localtileserver-0.6.4      |     pyhd8ed1ab_0        18.4 MB  conda-forge
#     palettable-3.3.3           |     pyhd8ed1ab_0          79 KB  conda-forge
#     server-thread-0.2.0        |     pyhd8ed1ab_0          11 KB  conda-forge
#     uvicorn-0.22.0             |  py311h1ea47a8_0         138 KB  conda-forge
#     werkzeug-2.1.2             |     pyhd8ed1ab_1         237 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        23.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   aniso8601          conda-forge/noarch::aniso8601-9.0.1-pyhd8ed1ab_0
#   flask              conda-forge/noarch::flask-2.1.3-pyhd8ed1ab_0
#   flask-caching      pkgs/main/noarch::flask-caching-1.10.1-pyhd3eb1b0_0
#   flask-cors         conda-forge/noarch::flask-cors-3.0.10-pyhd8ed1ab_0
#   flask-restx        conda-forge/noarch::flask-restx-1.0.6-pyhd8ed1ab_0
#   gdal               conda-forge/win-64::gdal-3.7.0-py311hf43951c_1
#   h11                conda-forge/noarch::h11-0.14.0-pyhd8ed1ab_0
#   itsdangerous       conda-forge/noarch::itsdangerous-2.1.2-pyhd8ed1ab_0
#   large-image        conda-forge/noarch::large-image-1.21.0-pyhd8ed1ab_0
#   large-image-sourc~ conda-forge/noarch::large-image-source-gdal-1.21.0-pyhd8ed1ab_0
#   localtileserver    conda-forge/noarch::localtileserver-0.6.4-pyhd8ed1ab_0
#   palettable         conda-forge/noarch::palettable-3.3.3-pyhd8ed1ab_0
#   server-thread      conda-forge/noarch::server-thread-0.2.0-pyhd8ed1ab_0
#   uvicorn            conda-forge/win-64::uvicorn-0.22.0-py311h1ea47a8_0
#   werkzeug           conda-forge/noarch::werkzeug-2.1.2-pyhd8ed1ab_1
#
#
#
# Downloading and Extracting Packages
#
# flask-caching-1.10.1 | 29 KB     |            |   0%
#
# large-image-source-g | 25 KB     |            |   0%
#
#
# h11-0.14.0           | 47 KB     |            |   0%
#
#
#
# aniso8601-9.0.1      | 38 KB     |            |   0%
#
#
#
#
# flask-restx-1.0.6    | 2.3 MB    |            |   0%
#
#
#
#
#
# werkzeug-2.1.2       | 237 KB    |            |   0%
#
#
#
#
#
#
# server-thread-0.2.0  | 11 KB     |            |   0%
#
#
#
#
#
#
#
# uvicorn-0.22.0       | 138 KB    |            |   0%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   |            |   0%
#
#
#
#
#
#
#
#
#
# large-image-1.21.0   | 61 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
# flask-cors-3.0.10    | 15 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# flask-2.1.3          | 71 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.7.0           | 1.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# itsdangerous-2.1.2   | 16 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# palettable-3.3.3     | 79 KB     |            |   0%
#
# large-image-source-g | 25 KB     | ######4    |  65%
# flask-caching-1.10.1 | 29 KB     | #####4     |  55%
#
# large-image-source-g | 25 KB     | ########## | 100%
#
#
#
# aniso8601-9.0.1      | 38 KB     | ####2      |  42%
#
#
#
#
# flask-restx-1.0.6    | 2.3 MB    |            |   1%
# flask-caching-1.10.1 | 29 KB     | ########## | 100%
#
#
#
#
#
# werkzeug-2.1.2       | 237 KB    | 6          |   7%
#
#
# h11-0.14.0           | 47 KB     | ###3       |  34%
#
#
#
# aniso8601-9.0.1      | 38 KB     | ########## | 100%
#
#
# h11-0.14.0           | 47 KB     | ########## | 100%
#
#
#
#
#
#
#
# uvicorn-0.22.0       | 138 KB    | #1         |  12%
#
#
#
#
# flask-restx-1.0.6    | 2.3 MB    | 9          |  10%
#
#
#
#
#
#
#
#
#
# large-image-1.21.0   | 61 KB     | ##6        |  26%
#
#
#
#
#
# werkzeug-2.1.2       | 237 KB    | ########## | 100%
#
#
#
#
#
# werkzeug-2.1.2       | 237 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# large-image-1.21.0   | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
# flask-cors-3.0.10    | 15 KB     | ########## | 100%
#
#
#
#
#
#
#
# uvicorn-0.22.0       | 138 KB    | ########## | 100%
#
#
#
#
#
#
#
# uvicorn-0.22.0       | 138 KB    | ########## | 100%
#
#
#
#
# flask-restx-1.0.6    | 2.3 MB    | ###3       |  33%
#
#
#
#
#
#
#
#
#
#
# flask-cors-3.0.10    | 15 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# flask-2.1.3          | 71 KB     | ##2        |  23%
#
#
#
#
#
#
# server-thread-0.2.0  | 11 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | 1          |   2%
#
#
#
#
#
#
# server-thread-0.2.0  | 11 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# flask-2.1.3          | 71 KB     | ########## | 100%
#
#
#
#
# flask-restx-1.0.6    | 2.3 MB    | ######7    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.7.0           | 1.5 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# itsdangerous-2.1.2   | 16 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# itsdangerous-2.1.2   | 16 KB     | ########## | 100%
#
#
#
#
# flask-restx-1.0.6    | 2.3 MB    | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# palettable-3.3.3     | 79 KB     | ##         |  20%
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.7.0           | 1.5 MB    | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# palettable-3.3.3     | 79 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | 6          |   7%
#
#
#
#
# flask-restx-1.0.6    | 2.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.7.0           | 1.5 MB    | ##7        |  28%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.7.0           | 1.5 MB    | #####7     |  57%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | #4         |  14%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | #9         |  20%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | ##5        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.7.0           | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.7.0           | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | ###6       |  37%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | ####2      |  43%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | ####9      |  49%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | #####5     |  55%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | ######1    |  61%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | ######7    |  67%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | #######3   |  73%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | #######9   |  80%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | ########5  |  86%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | #########1 |  92%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | #########7 |  98%
#
#
#
#
#
#
#
#
# localtileserver-0.6. | 18.4 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
